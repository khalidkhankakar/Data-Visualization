# %%
import matplotlib.pyplot as plt 
import numpy as np
# import seaborn as sns
# import pandas as pd
import scipy.stats as stats

# %%
# Poisson Distribution
# Parameters
mu = 10
x = np.arange(0, 30)

# Probability Mass Function
pmf = stats.poisson.pmf(x, mu)

# %%
#  plot graph
plt.bar(x, pmf,  color='blue', edgecolor='red')
# show axises and title
plt.xlabel('Number of occurrences')
plt.ylabel('Probability')
plt.title('Poisson Distribution') 
plt.show()

# %%
# Hypergeometric Distribution
# Parameters
N = 20 # size
K = 6 # number of successes
n = 13 # number of trials
x = np.arange(0, n+1) # Possible successful outcomes

pmf = stats.hypergeom.pmf(x, N, K, n)
print(pmf)
# Out:
# [1.80598555e-04 7.04334365e-03 7.04334365e-02 2.58255934e-01
#  3.87383901e-01 2.32430341e-01 4.42724458e-02 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]

# %%
# Make the plot
plt.bar(x, pmf, color='blue', edgecolor='red')
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.title('Hypergeometric Distribution')
plt.show()
