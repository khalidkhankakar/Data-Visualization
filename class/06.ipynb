# %%
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
import pandas as pd

# %%
x1 = np.random.rand(50)
y1 = np.random.rand(50)


x2 = np.random.rand(50)
y2 = np.random.rand(50) + 1



x3 = np.random.rand(50)
y3 = np.random.rand(50) + 2

# %%
plt.scatter(x1, y1, label='Data 1', color='red',marker='o')
plt.scatter(x2, y2, label='Data 2', color='blue',marker='s')
plt.scatter(x3, y3, label='Data 3', color='green',marker='^')

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Multiple scatter plot')
plt.legend()
plt.show()

# %%
x1 = [2,3,4,7,4]
y1 = [4,7,9,3,4]


x2 = [1,7,4,3,5]
y2 = [8,5,4,3,6]



x3 =[4,5,6,7,8]
y3 = [1,2,3,4,5]

# %%
plt.scatter(x1, y1, label='Data 1', color='purple',marker='o')
plt.scatter(x2, y2, label='Data 2', color='green',marker='^')
plt.scatter(x3, y3, label='Data 3', color='black',marker='+')

# plt.plot(x1, y1, label='Data 1', color='purple',marker='o')
# plt.plot(x2, y2, label='Data 2', color='green',marker='^')
# plt.plot(x3, y3, label='Data 3', color='black',marker='+')

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Multiple scatter plot')
plt.legend()
plt.show()

# %%
# joint plot
data = sns.load_dataset('iris')
data.head()
sns.jointplot(x='sepal_length', y='sepal_width', data=data,kind='kde')
#  give the title 
plt.title('Joint plot')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
my_data = pd.DataFrame({
    'W':np.random.rand(10),
    'X':np.random.rand(10),
    'Y':np.random.rand(10),
    'Z':np.random.rand(10)
})

sns.pairplot(my_data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as   sns
import pandas as pd

# %%
x1 = [2,3,4,7,4]
y1 = [3,4,5,6,7]

x2 = [1,7,4,3,5]
y2 = [8,5,4,3,6]

x3 =[4,5,6,7,8]
y3 = [1,2,3,4,5]


plt.scatter(x1,y1,label='Data 1', color='red',marker='o')
plt.scatter(x2,y2,label='Data 2', color='blue',marker='s')
plt.scatter(x3,y3,label='Data 3', color='green',marker='^')

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Multiple scatter plot')
plt.legend()
plt.show()

# %%
# create data (replace with your data )
data = sns.load_dataset('iris')
data

# create pair plot 
sns.pairplot(data,hue='species')

plt.title('Pair plot of iris dataset')
plt.show()

# %%
import plotly.express as px

# Simple data
labels = ['Sleep', 'Work', 'Exercise', 'Leisure']
values = [8, 9, 1, 6]

# Create pie chart
fig = px.pie(
    names=labels,
    values=values,
    title='Daily Activities'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 14
#       7 # Create pie chart
#       8 fig = px.pie(
#       9     names=labels,
#      10     values=values,
#      11     title='Daily Activities'
#      12 )
# ---> 14 fig.show()
#
# File d:\coding playground\Data visualization\venv\Lib\site-packages\plotly\basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)   3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File d:\coding playground\Data visualization\venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
# ...

# %%
# pip install plotly
